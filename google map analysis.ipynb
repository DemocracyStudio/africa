# %% [markdown]
# # Google Map analysis of the supermarkets in five African cities
# - Cape Town, South Africa
# - Lomé, Togo
# - Yaoundé, Cameroon
# - Nairobi, Kenya
# - Addis Ababa, Ethiopia
#
# ### 1. List all supermarkets of each city
# - Collect latitude/longitude for each supermarket
# - Filter out errors of scraping by cross-validation with lat/long
#
# ### 2. Scrape google map reviews for each supermarket
# - Collect reviewer's name, rating, and body of the review
# - Clean the data collected
#
# ### 3. Exploratory Data Analysis
# - What is the mean rating of supermarkets for each city?
# - What is the mean number of reviews by supermarkets?
# - What is the category of supermarket for each city?
# - How many supermarkets propose delivery services in each city?
# - How many are closed on sundays?
# - Delivery services and/or sundays closed is it affecting supermarket rating?
# - Can we identify spatial correlation of positive ratings? are there geographical clusters of good or bad reviews?
#
# ### 5. visualisation on maps
# - pinpoint supermarket ratings on a map
# - heatmap supermarket ratings

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

import pysal # cross-platform library for geospatial data science
#from pysal import weights, esda 
from esda.moran import Moran, Moran_Local

import splot
from splot.esda import moran_scatterplot, plot_moran, lisa_cluster

#import googlemaps
#from selenium import webdriver
#from parsel import Selector
from random import randint
from time import sleep

#from geopy.geocoders import Nominatim
#from geopy.extra.rate_limiter import RateLimiter

import folium
from folium.plugins import HeatMap

import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Note: previously scraped urls for supermarkets in five case study cities

# %%
# googlemaps supermarkets urls from phantombuster
supermarkets = pd.read_csv('/Users/juliencarbonnell/Desktop/African Urban Research/datasets/GM_supermarkets.csv')

# %%
supermarkets
# Out:
#                                                placeurl  \
# 0     https://www.google.com/maps/place/S.E.+Superma...
# 1     https://www.google.com/maps/place/R+%26+K+Supe...
# 2     https://www.google.com/maps/place/Family+Super...
# 3     https://www.google.com/maps/place/City+Cafe+%2...
# 4     https://www.google.com/maps/place/Best+Price+S...
# ...                                                 ...
# 1035  https://www.google.com/maps/place/Lomyad+Super...
# 1036  https://www.google.com/maps/place/Safeway+Supe...
# 1037  https://www.google.com/maps/place/Amanda+Super...
# 1038  https://www.google.com/maps/place/Wina+Superma...
# 1039  https://www.google.com/maps/place/Ready+superm...
#
#                                         title  rating  reviewcount  \
# 0                           S.E. Supermarkets     4.7         68.0
# 1                           R & K Supermarket     NaN          NaN
# 2                          Family Supermarket     NaN          NaN
# 3                    City Cafe & Supermarkets     5.0          1.0
# 4                      Best Price Supermarket     NaN          NaN
# ...                                       ...     ...          ...
# 1035                       Lomyad Supermarket     4.0          4.0
# 1036                      Safeway Supermarket     4.0         18.0
# 1037                       Amanda Supermarket     NaN          NaN
# 1038  Wina Supermarket And Juice Shola Branch     4.5          4.0
# 1039          Ready supermarket | ረዲ ሱፐር ማርኬት     4.5         11.0
#
#            category            attributes  \
# 0       Supermarket  ·  In-store shopping
# 1     Grocery store  ·  In-store shopping
# 2     Grocery store  ·  In-store shopping
# 3     Grocery store  ·  In-store shopping
# 4     Grocery store                   NaN
# ...             ...                   ...
# 1035  Shopping mall                   NaN
# 1036  Shopping mall                   NaN
# 1037  Shopping mall                   NaN
# 1038     Restaurant            ·  Takeout
# 1039  Shopping mall                   NaN
#
#                                                 address          wednesday  \
# 0     52 Roodebloem Rd, Woodstock, Cape Town, 7915, ...         7:30AM–8PM
# 1             Salt River, Cape Town, 7925, South Africa                NaN
# 2     Cape Town City Centre, Cape Town, 8000, South ...                NaN
# 3     Shop 6A, 31A Long St, Cape Town City Centre, C...            8AM–7PM
# 4             Salt River, Cape Town, 7925, South Africa                NaN
# ...                                                 ...                ...
# 1035                    2RCQ+F9C, Addis Ababa, Ethiopia    7:30a.m.–11p.m.
# 1036                    2V82+6HR, Addis Ababa, Ethiopia      12a.m.–11p.m.
# 1037                    2RCQ+FQR, Addis Ababa, Ethiopia                NaN
# 1038                    2PWW+WVF, Addis Ababa, Ethiopia        8a.m.–9p.m.
# 1039                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
#
#                thursday             friday           saturday  \
# 0            7:30AM–8PM         7:30AM–8PM         7:30AM–8PM
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3               8AM–7PM            8AM–7PM            8AM–7PM
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 1035    7:30a.m.–11p.m.    7:30a.m.–11p.m.    7:30a.m.–11p.m.
# 1036      12a.m.–11p.m.      12a.m.–11p.m.      12a.m.–11p.m.
# 1037                NaN                NaN                NaN
# 1038        8a.m.–9p.m.        8a.m.–9p.m.        8a.m.–9p.m.
# 1039  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.
#
#                  sunday             monday            tuesday  \
# 0            7:30AM–8PM         7:30AM–8PM         7:30AM–8PM
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3               8AM–7PM            8AM–7PM            8AM–7PM
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 1035    7:30a.m.–11p.m.    7:30a.m.–11p.m.    7:30a.m.–11p.m.
# 1036      12a.m.–11p.m.      12a.m.–11p.m.      12a.m.–11p.m.
# 1037                NaN                NaN                NaN
# 1038        8a.m.–9p.m.        8a.m.–9p.m.        8a.m.–9p.m.
# 1039  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.
#
#                               info  \
# 0     Hours or services may differ
# 1     Hours or services may differ
# 2     Hours or services may differ
# 3     Hours or services may differ
# 4                              NaN
# ...                            ...
# 1035                           NaN
# 1036                           NaN
# 1037                           NaN
# 1038                           NaN
# 1039                           NaN
#
#                                                  imgurl   latitude  longitude  \
# 0     https://lh5.googleusercontent.com/p/AF1QipOJZx... -33.933313  18.451812
# 1     https://www.gstatic.com/images/icons/material/... -33.928938  18.462562
# 2     https://lh5.googleusercontent.com/p/AF1QipNre6... -33.919438  18.424813
# 3     https://lh6.googleusercontent.com/proxy/yEvgHH... -33.920313  18.421813
# 4     https://maps.gstatic.com/tactile/pane/default_... -33.928438  18.460437
# ...                                                 ...        ...        ...
# 1035  https://maps.gstatic.com/tactile/pane/default_...        NaN        NaN
# 1036  https://www.gstatic.com/images/icons/material/...        NaN        NaN
# 1037  https://maps.gstatic.com/tactile/pane/default_...        NaN        NaN
# 1038  https://lh5.googleusercontent.com/p/AF1QipPSlz...        NaN        NaN
# 1039  https://lh5.googleusercontent.com/p/AF1QipN5aq...        NaN        NaN
#
#            query
# 0       CapeTown
# 1       CapeTown
# 2       CapeTown
# 3       CapeTown
# 4       CapeTown
# ...          ...
# 1035  AddisAbaba
# 1036  AddisAbaba
# 1037  AddisAbaba
# 1038  AddisAbaba
# 1039  AddisAbaba
#
# [1040 rows x 19 columns]

# %%
# rename headers with lower case
supermarkets.columns= supermarkets.columns.str.lower()

# %%
# list columns
supermarkets.columns
# Out:
# Index(['placeurl', 'title', 'rating', 'reviewcount', 'category', 'attributes',
#        'address', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday',
#        'monday', 'tuesday', 'info', 'imgurl', 'latitude', 'longitude',
#        'query'],
#       dtype='object')

# %%
#check nulls
supermarkets.isna().sum()
# Out:
# placeurl         0
# title            1
# rating         229
# reviewcount    229
# category         3
# attributes     105
# address          2
# wednesday      294
# thursday       294
# friday         294
# saturday       294
# sunday         294
# monday         294
# tuesday        294
# info           905
# imgurl           1
# latitude       265
# longitude      265
# query            0
# dtype: int64

# %%
# drop useless columns
supermarkets=supermarkets.drop(['unnamed: 0',
                                'website',
                                'pluscode',
                                'phonenumber',
                                'currentstatus',
                                'isclaimed',
                                'timestamp'
                               ], axis=1)

# %%
# count query values
supermarkets['query'].value_counts()
# Out:
# Nairobi       267
# Lomé          200
# AddisAbaba    197
# CapeTown      192
# Yaoundé       184
# Name: query, dtype: int64

# %%
# rename query values with city names
cities = {'https://www.google.com/maps/search/supermarket/@-33.9236772,18.3865141,13z/data=!3m1!4b1': "CapeTown",
          'https://www.google.com/maps/search/supermarket/@6.1874341,1.1353437,11z/data=!3m1!4b1': "Lomé",
          'https://www.google.com/maps/search/supermarket/@3.873919,11.4754269,13z/data=!3m1!4b1': "Yaoundé",
          'https://www.google.com/maps/search/supermarket/@-1.3031622,36.5672034,10z/data=!3m1!4b1': "Nairobi",
          'https://www.google.com/maps/search/supermarket/@8.9630978,38.6380589,11z/data=!3m1!4b1': "AddisAbaba"
         }
supermarkets['query'] = supermarkets['query'].replace(cities)
# be careful : this brings errors. need to fix it

# %%
# how many supermarkets listed for each city?
supermarkets['query'].value_counts()
# Out:
# Nairobi       267
# Lomé          200
# AddisAbaba    197
# CapeTown      192
# Yaoundé       184
# Name: query, dtype: int64

# %%
# is there null lat/long values ?
print(supermarkets['latitude'].isnull().groupby([supermarkets['query']]).sum())
print(supermarkets['longitude'].isnull().groupby([supermarkets['query']]).sum())
# Out:
# query
# AddisAbaba    110
# CapeTown        1
# Lomé           42
# Nairobi        39
# Yaoundé        73
# Name: latitude, dtype: int64
# query
# AddisAbaba    110
# CapeTown        1
# Lomé           42
# Nairobi        39
# Yaoundé        73
# Name: longitude, dtype: int64

# %% [markdown]
# ### get missing lat/long from address

# %%
# list missing lat/long in a new df
missinglat = supermarkets[supermarkets['latitude'].isnull()]
# drop null addresses
missinglat = missinglat[missinglat['address'].notna()]
# reset index
missinglat = missinglat.reset_index(drop=True)
missinglat
# Out:
#                                               placeurl  \
# 0    https://www.google.com/maps/place/Super+Source...
# 1    https://www.google.com/maps/place/Elidec+Shopr...
# 2    https://www.google.com/maps/place/Alice+Provis...
# 3    https://www.google.com/maps/place/Kenecab/data...
# 4    https://www.google.com/maps/place/Adzodogu+Min...
# ..                                                 ...
# 258  https://www.google.com/maps/place/Lomyad+Super...
# 259  https://www.google.com/maps/place/Safeway+Supe...
# 260  https://www.google.com/maps/place/Amanda+Super...
# 261  https://www.google.com/maps/place/Wina+Superma...
# 262  https://www.google.com/maps/place/Ready+superm...
#
#                                        title  rating  reviewcount  \
# 0                              Super Sources     NaN          NaN
# 1                            Elidec Shoprite     NaN          NaN
# 2                      Alice Provision Store     NaN          NaN
# 3                                    Kenecab     3.9         14.0
# 4               Adzodogu Mini Market Aflaoga     5.0          1.0
# ..                                       ...     ...          ...
# 258                       Lomyad Supermarket     4.0          4.0
# 259                      Safeway Supermarket     4.0         18.0
# 260                       Amanda Supermarket     NaN          NaN
# 261  Wina Supermarket And Juice Shola Branch     4.5          4.0
# 262          Ready supermarket | ረዲ ሱፐር ማርኬት     4.5         11.0
#
#           category            attributes  \
# 0    Grocery store                   NaN
# 1    Grocery store  ·  In-store shopping
# 2    Grocery store  ·  In-store shopping
# 3    Grocery store  ·  In-store shopping
# 4    Grocery store                   NaN
# ..             ...                   ...
# 258  Shopping mall                   NaN
# 259  Shopping mall                   NaN
# 260  Shopping mall                   NaN
# 261     Restaurant            ·  Takeout
# 262  Shopping mall                   NaN
#
#                                                address          wednesday  \
# 0    South Ln, Rondebosch, Cape Town, 8005, South A...            9AM–5PM
# 1                              62J3+Q33, Dzodze, Ghana                NaN
# 2                              6XMW+R9V, Dzodze, Ghana                NaN
# 3                                3V66+JC2, Abor, Ghana         7AM–9:30PM
# 4                                45CP+9MF, Denu, Ghana                NaN
# ..                                                 ...                ...
# 258                    2RCQ+F9C, Addis Ababa, Ethiopia    7:30a.m.–11p.m.
# 259                    2V82+6HR, Addis Ababa, Ethiopia      12a.m.–11p.m.
# 260                    2RCQ+FQR, Addis Ababa, Ethiopia                NaN
# 261                    2PWW+WVF, Addis Ababa, Ethiopia        8a.m.–9p.m.
# 262                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
#
#               thursday             friday           saturday  \
# 0              9AM–5PM            9AM–5PM             Closed
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3           7AM–9:30PM         7AM–9:30PM         7AM–9:30PM
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 258    7:30a.m.–11p.m.    7:30a.m.–11p.m.    7:30a.m.–11p.m.
# 259      12a.m.–11p.m.      12a.m.–11p.m.      12a.m.–11p.m.
# 260                NaN                NaN                NaN
# 261        8a.m.–9p.m.        8a.m.–9p.m.        8a.m.–9p.m.
# 262  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.
#
#                 sunday             monday            tuesday  \
# 0               Closed            9AM–5PM            9AM–5PM
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3           7AM–9:30PM         7AM–9:30PM         7AM–9:30PM
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 258    7:30a.m.–11p.m.    7:30a.m.–11p.m.    7:30a.m.–11p.m.
# 259      12a.m.–11p.m.      12a.m.–11p.m.      12a.m.–11p.m.
# 260                NaN                NaN                NaN
# 261        8a.m.–9p.m.        8a.m.–9p.m.        8a.m.–9p.m.
# 262  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.
#
#                              info  \
# 0    Hours or services may differ
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 258                           NaN
# 259                           NaN
# 260                           NaN
# 261                           NaN
# 262                           NaN
#
#                                                 imgurl  latitude  longitude  \
# 0    https://www.gstatic.com/images/icons/material/...       NaN        NaN
# 1    https://www.gstatic.com/images/icons/material/...       NaN        NaN
# 2    https://www.gstatic.com/images/icons/material/...       NaN        NaN
# 3    https://www.gstatic.com/images/icons/material/...       NaN        NaN
# 4    https://www.gstatic.com/images/icons/material/...       NaN        NaN
# ..                                                 ...       ...        ...
# 258  https://maps.gstatic.com/tactile/pane/default_...       NaN        NaN
# 259  https://www.gstatic.com/images/icons/material/...       NaN        NaN
# 260  https://maps.gstatic.com/tactile/pane/default_...       NaN        NaN
# 261  https://lh5.googleusercontent.com/p/AF1QipPSlz...       NaN        NaN
# 262  https://lh5.googleusercontent.com/p/AF1QipN5aq...       NaN        NaN
#
#           query
# 0      CapeTown
# 1          Lomé
# 2          Lomé
# 3          Lomé
# 4          Lomé
# ..          ...
# 258  AddisAbaba
# 259  AddisAbaba
# 260  AddisAbaba
# 261  AddisAbaba
# 262  AddisAbaba
#
# [263 rows x 19 columns]

# %%
# try geolocator for one value
geolocator = Nominatim(user_agent='julien.carbonnell@gmail.com')
location = geolocator.geocode(missinglat['address'][0])
location
# Out:
# Location(South Lane, Rondebosch, Cape Town Ward 59, Cape Town, City of Cape Town, Western Cape, CAPE TOWN, South Africa, (-33.9577131, 18.459655, 0.0))

# %%
print(location.latitude)
print(location.longitude)
# Out:
# -33.9577131
# 18.459655

# %%
location = geolocator.geocode(missinglat['address'][1])
location
print(missinglat['address'][1])
# Out:
# 62J3+Q33, Dzodze, Ghana

# %% [markdown]
# ### most address are recorded with weird code e.g. XQJF+2X8, and a lot are outside of the city targetted

# %%
# select rows only if address mentions the city targetted
validlocation = missinglat[missinglat['address'].str.contains("Cape Town")]
validlocation
# Out:
#                                             placeurl          title  rating  \
# 0  https://www.google.com/maps/place/Super+Source...  Super Sources     NaN
#
#    reviewcount       category attributes  \
# 0          NaN  Grocery store        NaN
#
#                                              address wednesday thursday  \
# 0  South Ln, Rondebosch, Cape Town, 8005, South A...   9AM–5PM  9AM–5PM
#
#     friday  ...   monday  tuesday                          info  \
# 0  9AM–5PM  ...  9AM–5PM  9AM–5PM  Hours or services may differ
#
#                                               imgurl   latitude  longitude  \
# 0  https://www.gstatic.com/images/icons/material/... -33.957713  18.459655
#
#       query                                           location  \
# 0  CapeTown  (South Lane, Rondebosch, Cape Town Ward 59, Ca...
#
#                            point altitude
# 0  (-33.9577131, 18.459655, 0.0)      0.0
#
# [1 rows x 22 columns]

# %%
#append the other cities
validlocation = validlocation.append(missinglat[missinglat['address'].str.contains("Lomé")])
validlocation = validlocation.append(missinglat[missinglat['address'].str.contains("Yaoundé")])
validlocation = validlocation.append(missinglat[missinglat['address'].str.contains("Nairobi")])
validlocation = validlocation.append(missinglat[missinglat['address'].str.contains("Addis Ababa")])
# reset index
validlocation = validlocation.reset_index(drop=True)
validlocation
# Out:
#                                               placeurl  \
# 0    https://www.google.com/maps/place/Super+Source...
# 1    https://www.google.com/maps/place/Supermarch%C...
# 2    https://www.google.com/maps/place/GIONA+Supere...
# 3    https://www.google.com/maps/place/Super+March%...
# 4    https://www.google.com/maps/place/CM+PETROLEUM...
# ..                                                 ...
# 216  https://www.google.com/maps/place/Lomyad+Super...
# 217  https://www.google.com/maps/place/Safeway+Supe...
# 218  https://www.google.com/maps/place/Amanda+Super...
# 219  https://www.google.com/maps/place/Wina+Superma...
# 220  https://www.google.com/maps/place/Ready+superm...
#
#                                        title  rating  reviewcount  \
# 0                              Super Sources     NaN          NaN
# 1                        Supermarché ALZARAA     3.0         11.0
# 2                            GIONA Superette     3.5          4.0
# 3             Super Marché Miséricordia Vrai     NaN          NaN
# 4                    CM PETROLEUM AKODESSEWA     NaN          NaN
# ..                                       ...     ...          ...
# 216                       Lomyad Supermarket     4.0          4.0
# 217                      Safeway Supermarket     4.0         18.0
# 218                       Amanda Supermarket     NaN          NaN
# 219  Wina Supermarket And Juice Shola Branch     4.5          4.0
# 220          Ready supermarket | ረዲ ሱፐር ማርኬት     4.5         11.0
#
#           category                                         attributes  \
# 0    Grocery store                                                NaN
# 1      Supermarket                               ·  In-store shopping
# 2      Supermarket  ·  In-store shopping  ·  In-store pick-up  ·  ...
# 3      Supermarket                               ·  In-store shopping
# 4      Supermarket                               ·  In-store shopping
# ..             ...                                                ...
# 216  Shopping mall                                                NaN
# 217  Shopping mall                                                NaN
# 218  Shopping mall                                                NaN
# 219     Restaurant                                         ·  Takeout
# 220  Shopping mall                                                NaN
#
#                                                address          wednesday  \
# 0    South Ln, Rondebosch, Cape Town, 8005, South A...            9AM–5PM
# 1                                 65PX+3XC, Lomé, Togo            8AM–9PM
# 2                                 646M+55X, Lomé, Togo                NaN
# 3                                 658C+V77, Lomé, Togo                NaN
# 4                                 5749+62W, Lomé, Togo           8AM–10PM
# ..                                                 ...                ...
# 216                    2RCQ+F9C, Addis Ababa, Ethiopia    7:30a.m.–11p.m.
# 217                    2V82+6HR, Addis Ababa, Ethiopia      12a.m.–11p.m.
# 218                    2RCQ+FQR, Addis Ababa, Ethiopia                NaN
# 219                    2PWW+WVF, Addis Ababa, Ethiopia        8a.m.–9p.m.
# 220                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
#
#               thursday             friday  ...             monday  \
# 0              9AM–5PM            9AM–5PM  ...            9AM–5PM
# 1              8AM–9PM            8AM–9PM  ...            8AM–9PM
# 2                  NaN                NaN  ...                NaN
# 3                  NaN                NaN  ...                NaN
# 4             8AM–10PM           8AM–10PM  ...           8AM–10PM
# ..                 ...                ...  ...                ...
# 216    7:30a.m.–11p.m.    7:30a.m.–11p.m.  ...    7:30a.m.–11p.m.
# 217      12a.m.–11p.m.      12a.m.–11p.m.  ...      12a.m.–11p.m.
# 218                NaN                NaN  ...                NaN
# 219        8a.m.–9p.m.        8a.m.–9p.m.  ...        8a.m.–9p.m.
# 220  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  ...  6:30a.m.–1:30p.m.
#
#                tuesday                          info  \
# 0              9AM–5PM  Hours or services may differ
# 1              8AM–9PM                           NaN
# 2                  NaN                           NaN
# 3                  NaN                           NaN
# 4             8AM–10PM                           NaN
# ..                 ...                           ...
# 216    7:30a.m.–11p.m.                           NaN
# 217      12a.m.–11p.m.                           NaN
# 218                NaN                           NaN
# 219        8a.m.–9p.m.                           NaN
# 220  6:30a.m.–1:30p.m.                           NaN
#
#                                                 imgurl   latitude  longitude  \
# 0    https://www.gstatic.com/images/icons/material/... -33.957713  18.459655
# 1    https://lh5.googleusercontent.com/p/AF1QipPnZi...        NaN        NaN
# 2    https://lh5.googleusercontent.com/p/AF1QipPQaN...        NaN        NaN
# 3    https://lh5.googleusercontent.com/p/AF1QipNAxM...        NaN        NaN
# 4    https://lh5.googleusercontent.com/p/AF1QipOVqs...        NaN        NaN
# ..                                                 ...        ...        ...
# 216  https://maps.gstatic.com/tactile/pane/default_...        NaN        NaN
# 217  https://www.gstatic.com/images/icons/material/...        NaN        NaN
# 218  https://maps.gstatic.com/tactile/pane/default_...        NaN        NaN
# 219  https://lh5.googleusercontent.com/p/AF1QipPSlz...        NaN        NaN
# 220  https://lh5.googleusercontent.com/p/AF1QipN5aq...        NaN        NaN
#
#           query                                           location  \
# 0      CapeTown  (South Lane, Rondebosch, Cape Town Ward 59, Ca...
# 1          Lomé                                               None
# 2          Lomé                                               None
# 3          Lomé                                               None
# 4          Lomé                                               None
# ..          ...                                                ...
# 216  AddisAbaba                                               None
# 217  AddisAbaba                                               None
# 218  AddisAbaba                                               None
# 219  AddisAbaba                                               None
# 220  AddisAbaba                                               None
#
#                              point altitude
# 0    (-33.9577131, 18.459655, 0.0)      0.0
# 1                             None      NaN
# 2                             None      NaN
# 3                             None      NaN
# 4                             None      NaN
# ..                             ...      ...
# 216                           None      NaN
# 217                           None      NaN
# 218                           None      NaN
# 219                           None      NaN
# 220                           None      NaN
#
# [221 rows x 22 columns]

# %%
# replace missinglat with validlocation
missinglat = validlocation
missinglat
# Out:
#                                               placeurl  \
# 0    https://www.google.com/maps/place/Super+Source...
# 1    https://www.google.com/maps/place/Supermarch%C...
# 2    https://www.google.com/maps/place/GIONA+Supere...
# 3    https://www.google.com/maps/place/Super+March%...
# 4    https://www.google.com/maps/place/CM+PETROLEUM...
# ..                                                 ...
# 216  https://www.google.com/maps/place/Lomyad+Super...
# 217  https://www.google.com/maps/place/Safeway+Supe...
# 218  https://www.google.com/maps/place/Amanda+Super...
# 219  https://www.google.com/maps/place/Wina+Superma...
# 220  https://www.google.com/maps/place/Ready+superm...
#
#                                        title  rating  reviewcount  \
# 0                              Super Sources     NaN          NaN
# 1                        Supermarché ALZARAA     3.0         11.0
# 2                            GIONA Superette     3.5          4.0
# 3             Super Marché Miséricordia Vrai     NaN          NaN
# 4                    CM PETROLEUM AKODESSEWA     NaN          NaN
# ..                                       ...     ...          ...
# 216                       Lomyad Supermarket     4.0          4.0
# 217                      Safeway Supermarket     4.0         18.0
# 218                       Amanda Supermarket     NaN          NaN
# 219  Wina Supermarket And Juice Shola Branch     4.5          4.0
# 220          Ready supermarket | ረዲ ሱፐር ማርኬት     4.5         11.0
#
#           category                                         attributes  \
# 0    Grocery store                                                NaN
# 1      Supermarket                               ·  In-store shopping
# 2      Supermarket  ·  In-store shopping  ·  In-store pick-up  ·  ...
# 3      Supermarket                               ·  In-store shopping
# 4      Supermarket                               ·  In-store shopping
# ..             ...                                                ...
# 216  Shopping mall                                                NaN
# 217  Shopping mall                                                NaN
# 218  Shopping mall                                                NaN
# 219     Restaurant                                         ·  Takeout
# 220  Shopping mall                                                NaN
#
#                                                address          wednesday  \
# 0    South Ln, Rondebosch, Cape Town, 8005, South A...            9AM–5PM
# 1                                 65PX+3XC, Lomé, Togo            8AM–9PM
# 2                                 646M+55X, Lomé, Togo                NaN
# 3                                 658C+V77, Lomé, Togo                NaN
# 4                                 5749+62W, Lomé, Togo           8AM–10PM
# ..                                                 ...                ...
# 216                    2RCQ+F9C, Addis Ababa, Ethiopia    7:30a.m.–11p.m.
# 217                    2V82+6HR, Addis Ababa, Ethiopia      12a.m.–11p.m.
# 218                    2RCQ+FQR, Addis Ababa, Ethiopia                NaN
# 219                    2PWW+WVF, Addis Ababa, Ethiopia        8a.m.–9p.m.
# 220                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
#
#               thursday             friday  ...             monday  \
# 0              9AM–5PM            9AM–5PM  ...            9AM–5PM
# 1              8AM–9PM            8AM–9PM  ...            8AM–9PM
# 2                  NaN                NaN  ...                NaN
# 3                  NaN                NaN  ...                NaN
# 4             8AM–10PM           8AM–10PM  ...           8AM–10PM
# ..                 ...                ...  ...                ...
# 216    7:30a.m.–11p.m.    7:30a.m.–11p.m.  ...    7:30a.m.–11p.m.
# 217      12a.m.–11p.m.      12a.m.–11p.m.  ...      12a.m.–11p.m.
# 218                NaN                NaN  ...                NaN
# 219        8a.m.–9p.m.        8a.m.–9p.m.  ...        8a.m.–9p.m.
# 220  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  ...  6:30a.m.–1:30p.m.
#
#                tuesday                          info  \
# 0              9AM–5PM  Hours or services may differ
# 1              8AM–9PM                           NaN
# 2                  NaN                           NaN
# 3                  NaN                           NaN
# 4             8AM–10PM                           NaN
# ..                 ...                           ...
# 216    7:30a.m.–11p.m.                           NaN
# 217      12a.m.–11p.m.                           NaN
# 218                NaN                           NaN
# 219        8a.m.–9p.m.                           NaN
# 220  6:30a.m.–1:30p.m.                           NaN
#
#                                                 imgurl   latitude  longitude  \
# 0    https://www.gstatic.com/images/icons/material/... -33.957713  18.459655
# 1    https://lh5.googleusercontent.com/p/AF1QipPnZi...        NaN        NaN
# 2    https://lh5.googleusercontent.com/p/AF1QipPQaN...        NaN        NaN
# 3    https://lh5.googleusercontent.com/p/AF1QipNAxM...        NaN        NaN
# 4    https://lh5.googleusercontent.com/p/AF1QipOVqs...        NaN        NaN
# ..                                                 ...        ...        ...
# 216  https://maps.gstatic.com/tactile/pane/default_...        NaN        NaN
# 217  https://www.gstatic.com/images/icons/material/...        NaN        NaN
# 218  https://maps.gstatic.com/tactile/pane/default_...        NaN        NaN
# 219  https://lh5.googleusercontent.com/p/AF1QipPSlz...        NaN        NaN
# 220  https://lh5.googleusercontent.com/p/AF1QipN5aq...        NaN        NaN
#
#           query                                           location  \
# 0      CapeTown  (South Lane, Rondebosch, Cape Town Ward 59, Ca...
# 1          Lomé                                               None
# 2          Lomé                                               None
# 3          Lomé                                               None
# 4          Lomé                                               None
# ..          ...                                                ...
# 216  AddisAbaba                                               None
# 217  AddisAbaba                                               None
# 218  AddisAbaba                                               None
# 219  AddisAbaba                                               None
# 220  AddisAbaba                                               None
#
#                              point altitude
# 0    (-33.9577131, 18.459655, 0.0)      0.0
# 1                             None      NaN
# 2                             None      NaN
# 3                             None      NaN
# 4                             None      NaN
# ..                             ...      ...
# 216                           None      NaN
# 217                           None      NaN
# 218                           None      NaN
# 219                           None      NaN
# 220                           None      NaN
#
# [221 rows x 22 columns]

# %%
# check if wrong location have disappeared
location = geolocator.geocode(missinglat['address'][1])
location
print(missinglat['address'][1])
# Out:
# 65PX+3XC, Lomé, Togo

# %% [raw]
# # get lat/long from geocode with open street map
# geolocator = Nominatim(user_agent='julien.carbonnell@gmail.com')
# missinglat['latitude']=''
# missinglat['longitude']=''
#
# for i in range(missinglat.shape[0]):
#     location = geolocator.geocode(missinglat['address'][i])
#     missinglat['latitude'][i]= location.latitude
#     missinglat['longitude'][i]= location.longitude
#     sleep(1)

# %% [raw]
# # get lat/long geocode with open street map (other code)
# geolocator = Nominatim(user_agent='julien.carbonnell@gmail.com')
#
# # delay between geocoding calls
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# # create location column from address
# missinglat['location'] = missinglat['address'].apply(geocode)
# # get latitude, longitude, altitude from location
# missinglat['point'] = missinglat['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# # split point column into latitude, longitude and altitude columns
# missinglat[['latitude', 'longitude', 'altitude']] = pd.DataFrame(missinglat['point'].tolist(), index=missinglat.index)

# %%
missinglat.isna().sum()
# too many missing values remain
# Out:
# placeurl         0
# title            0
# rating          77
# reviewcount     77
# category         0
# attributes      35
# address          0
# wednesday       94
# thursday        94
# friday          94
# saturday        94
# sunday          94
# monday          94
# tuesday         94
# info           220
# imgurl           0
# latitude       220
# longitude      220
# query            0
# location       220
# point          220
# altitude       220
# dtype: int64

# %%
# check what does placeurl looks like
missinglat['placeurl'][1]
# Out:
# 'https://www.google.com/maps/place/Supermarch%C3%A9+ALZARAA/data=!4m5!3m4!1s0x1021581d9ebe81fd:0x7b848f3f4ce9898f!8m2!3d6.2351801!4d1.1998825'

# %%
# split the placeurl to get lat out of it
urlsplit = pd.concat([missinglat['placeurl'], missinglat['placeurl'].str.split('!3d', expand=True)], axis=1)
urlsplit.head()
# Out:
#                                             placeurl  \
# 0  https://www.google.com/maps/place/Super+Source...
# 1  https://www.google.com/maps/place/Supermarch%C...
# 2  https://www.google.com/maps/place/GIONA+Supere...
# 3  https://www.google.com/maps/place/Super+March%...
# 4  https://www.google.com/maps/place/CM+PETROLEUM...
#
#                                                    0                         1
# 0  https://www.google.com/maps/place/Super+Source...  -33.9577461!4d18.4598667
# 1  https://www.google.com/maps/place/Supermarch%C...     6.2351801!4d1.1998825
# 2  https://www.google.com/maps/place/GIONA+Supere...     6.2104762!4d1.1329886
# 3  https://www.google.com/maps/place/Super+March%...      6.2171574!4d1.170659
# 4  https://www.google.com/maps/place/CM+PETROLEUM...     6.1556064!4d1.2675667

# %%
# split the resulting collumn to get long out of it
urlsplit = pd.concat([urlsplit['placeurl'], urlsplit[1].str.split('!4d', expand=True)], axis=1)
urlsplit.head()
# Out:
#                                             placeurl            0           1
# 0  https://www.google.com/maps/place/Super+Source...  -33.9577461  18.4598667
# 1  https://www.google.com/maps/place/Supermarch%C...    6.2351801   1.1998825
# 2  https://www.google.com/maps/place/GIONA+Supere...    6.2104762   1.1329886
# 3  https://www.google.com/maps/place/Super+March%...    6.2171574    1.170659
# 4  https://www.google.com/maps/place/CM+PETROLEUM...    6.1556064   1.2675667

# %%
urlsplit.shape
# Out:
# (221, 3)

# %%
missinglat.shape
# Out:
# (221, 22)

# %%
# rename columns
urlsplit.rename(columns={0: 'latitude',
                       1: 'longitude'
                      }, inplace=True, errors='raise')

# %%
del urlsplit['placeurl']

# %% [raw]
# # delete lat / long columns in missing lat
# missinglat = missinglat.drop(['latitude',
#                               'longitude',
#                               'location',
#                               'point',
#                               'altitude'
#                              ], axis=1)

# %%
# concat lat/long values from missing lat df by the urlsplit ones
missinglat = missinglat.join(urlsplit)
missinglat = missinglat.reset_index(drop=True)
missinglat.head()
# Out:
#                                             placeurl  \
# 0  https://www.google.com/maps/place/Super+Source...
# 1  https://www.google.com/maps/place/Supermarch%C...
# 2  https://www.google.com/maps/place/GIONA+Supere...
# 3  https://www.google.com/maps/place/Super+March%...
# 4  https://www.google.com/maps/place/CM+PETROLEUM...
#
#                             title  rating  reviewcount       category  \
# 0                   Super Sources     NaN          NaN  Grocery store
# 1             Supermarché ALZARAA     3.0         11.0    Supermarket
# 2                 GIONA Superette     3.5          4.0    Supermarket
# 3  Super Marché Miséricordia Vrai     NaN          NaN    Supermarket
# 4         CM PETROLEUM AKODESSEWA     NaN          NaN    Supermarket
#
#                                           attributes  \
# 0                                                NaN
# 1                               ·  In-store shopping
# 2  ·  In-store shopping  ·  In-store pick-up  ·  ...
# 3                               ·  In-store shopping
# 4                               ·  In-store shopping
#
#                                              address wednesday  thursday  \
# 0  South Ln, Rondebosch, Cape Town, 8005, South A...   9AM–5PM   9AM–5PM
# 1                               65PX+3XC, Lomé, Togo   8AM–9PM   8AM–9PM
# 2                               646M+55X, Lomé, Togo       NaN       NaN
# 3                               658C+V77, Lomé, Togo       NaN       NaN
# 4                               5749+62W, Lomé, Togo  8AM–10PM  8AM–10PM
#
#      friday  saturday             sunday    monday   tuesday  \
# 0   9AM–5PM    Closed             Closed   9AM–5PM   9AM–5PM
# 1   8AM–9PM   8AM–9PM  8:30AM–2PM, 3–7PM   8AM–9PM   8AM–9PM
# 2       NaN       NaN                NaN       NaN       NaN
# 3       NaN       NaN                NaN       NaN       NaN
# 4  8AM–10PM  8AM–10PM           8AM–10PM  8AM–10PM  8AM–10PM
#
#                            info  \
# 0  Hours or services may differ
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                                               imgurl     query     latitude  \
# 0  https://www.gstatic.com/images/icons/material/...  CapeTown  -33.9577461
# 1  https://lh5.googleusercontent.com/p/AF1QipPnZi...      Lomé    6.2351801
# 2  https://lh5.googleusercontent.com/p/AF1QipPQaN...      Lomé    6.2104762
# 3  https://lh5.googleusercontent.com/p/AF1QipNAxM...      Lomé    6.2171574
# 4  https://lh5.googleusercontent.com/p/AF1QipOVqs...      Lomé    6.1556064
#
#     longitude
# 0  18.4598667
# 1   1.1998825
# 2   1.1329886
# 3    1.170659
# 4   1.2675667

# %%
missinglat['placeurl'][6]
# Out:
# 'https://www.google.com/maps/place/FIRST+MARKET/data=!4m5!3m4!1s0x1021585d38bc30c9:0xbef15782355fe035!8m2!3d6.2034887!4d1.1916575'

# %%
supermarkets['placeurl'][6]
# Out:
# "https://www.google.com/maps/place/Harry's+Supermarket/data=!4m5!3m4!1s0x1dcc6724b86be857:0xf5db44505e608fcb!8m2!3d-33.9139759!4d18.3912139"

# %%
print(missinglat['latitude'][6])
print(missinglat['longitude'][6])
# Out:
# 6.2034887
# 1.1916575

# %%
supermarkets.columns
# Out:
# Index(['placeurl', 'title', 'rating', 'reviewcount', 'category', 'attributes',
#        'address', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday',
#        'monday', 'tuesday', 'info', 'imgurl', 'latitude', 'longitude',
#        'query'],
#       dtype='object')

# %%
missinglat.columns
# Out:
# Index(['placeurl', 'title', 'rating', 'reviewcount', 'category', 'attributes',
#        'address', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday',
#        'monday', 'tuesday', 'info', 'imgurl', 'query', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
# align columns in both dataframes
missinglat = missinglat[['placeurl', 'title', 'rating', 'reviewcount', 'category', 'attributes',
       'address', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday',
       'monday', 'tuesday', 'info', 'imgurl', 'latitude', 'longitude',
       'query']]

# %%
# delete null latitude rows in original file
supermarkets = supermarkets[supermarkets['latitude'].notna()]
print(supermarkets['longitude'].isnull().sum())
# Out:
# 0

# %%
# append missinglat rows to original file
supermarkets = supermarkets.append(missinglat, ignore_index=True)
supermarkets

# %%
# how many lat/long keep missing ?
supermarkets.isna().sum()
# Out:
# placeurl         0
# title            0
# rating         219
# reviewcount    219
# category         2
# attributes      97
# address          0
# wednesday      279
# thursday       279
# friday         279
# saturday       279
# sunday         279
# monday         279
# tuesday        279
# info           862
# imgurl           0
# latitude         0
# longitude        0
# query            0
# dtype: int64

# %%
supermarkets.shape
# Out:
# (996, 19)

# %%
# save file
#supermarkets.to_csv('GM_supermarkets.csv', index=False)

# %% [markdown]
# ## Scrape the reviews for each supermarket

# %%
# scrape customer reviews based on urls
supermarkets['placeurl'][0]
# Out:
# 'https://www.google.com/maps/place/S.E.+Supermarkets/data=!4m5!3m4!1s0x1dcc5d0aae05dc67:0x502209aedfc8c871!8m2!3d-33.933285!4d18.4518531'

# %%
supermarkets['placeurl'][421]
# Out:
# 'https://www.google.com/maps/place/Fosak+Sarl/data=!4m5!3m4!1s0x108bcf007189df15:0x3eb9475e4fdea686!8m2!3d3.867464!4d11.5177656'

# %%
# start the browser
executable_path = '/usr/local/bin/chromedriver'
driver = webdriver.Chrome(executable_path)

# %%
# open reviews page
url = supermarkets['placeurl'][0]
driver.get(url)

# %%
# parse reviews
page_content = driver.page_source
response = Selector(page_content)

# %%
# iterate over the reviews
results = []

for el in response.xpath('//div/div[@data-review-id]/div[contains(@class, "content")]'):
    results.append({
        'title': el.xpath('.//div[contains(@class, "title")]/span/text()').extract_first(''),
        'rating': el.xpath('.//span[contains(@aria-label, "stars")]/@aria-label').extract_first('').replace('stars' ,'').strip(),
        'body': el.xpath('.//span[contains(@class, "text")]/text()').extract_first(''),
    })

print(results)
# Out:
# [{'title': 'Hair by Michelle and Beauty Parlour phala', 'rating': '5', 'body': "This is a go to supermarket, they go out of their way to satisfy clients. I've been going there for over a decade and always satisfied with their service."}, {'title': 'Jayan Smart', 'rating': '5', 'body': 'Simply the best corner store. Just make sure you are nice to Cloe!'}, {'title': 'Loretta Chan-Sam', 'rating': '5', 'body': "If you're looking for a consumer-friendly par excellence environment you're at the right place. Friendly, helpful and accommodating atmosphere with a good range of organic produce and a sure-fire bet to find that missing ingredient at the last minute ..."}]

# %%
# create empty column to fill
supermarkets['reviews'] = ''

# %%
# iterate through places in dataframe
count = 0

for i in range(supermarkets.shape[0]):
    print(count)
    try:
        driver.get(supermarkets['placeurl'][i])
        page_content = driver.page_source
        response = Selector(page_content)
        results = []
        for el in response.xpath('//div/div[@data-review-id]/div[contains(@class, "content")]'):
            results.append({
                'title': el.xpath('.//div[contains(@class, "title")]/span/text()').extract_first(''),
                'rating': el.xpath('.//span[contains(@aria-label, "stars")]/@aria-label').extract_first('').replace('stars' ,'').strip(),
                'body': el.xpath('.//span[contains(@class, "text")]/text()').extract_first(''),
            })
        supermarkets["reviews"][i] = results
        sleep(randint(10,100))
    except: pass
    count += 1

# %%
# check the result
supermarkets.tail()

# %%
# stop the browser before leaving
driver.quit
# Out:
# <bound method WebDriver.quit of <selenium.webdriver.chrome.webdriver.WebDriver (session="56fe66d079e19dfd91e0bf9022105484")>>

# %%
# save reviews dataframe
#supermarkets.to_csv('GM_reviews.csv', index=False)

# %% [markdown]
# ## Note: reviews scraping has been done in two rounds.
# #### append the two files contains reviews

# %%
# import reviews files
reviews = pd.read_csv('/Users/juliencarbonnell/Desktop/African Urban Research/datasets/GM_reviews.csv')

# %%
reviews
# Out:
#                                                placeurl  \
# 0     https://www.google.com/maps/place/S.E.+Superma...
# 1     https://www.google.com/maps/place/S.E.+Superma...
# 2     https://www.google.com/maps/place/S.E.+Superma...
# 3     https://www.google.com/maps/place/City+Cafe+%2...
# 4     https://www.google.com/maps/place/Brothers+Sup...
# ...                                                 ...
# 1927  https://www.google.com/maps/place/Wina+Superma...
# 1928  https://www.google.com/maps/place/Wina+Superma...
# 1929  https://www.google.com/maps/place/Ready+superm...
# 1930  https://www.google.com/maps/place/Ready+superm...
# 1931  https://www.google.com/maps/place/Ready+superm...
#
#                                     placename  overall_rating  reviewcount  \
# 0                           S.E. Supermarkets             4.7         68.0
# 1                           S.E. Supermarkets             4.7         68.0
# 2                           S.E. Supermarkets             4.7         68.0
# 3                    City Cafe & Supermarkets             5.0          1.0
# 4                        Brothers Supermarket             4.0          9.0
# ...                                       ...             ...          ...
# 1927  Wina Supermarket And Juice Shola Branch             4.5          4.0
# 1928  Wina Supermarket And Juice Shola Branch             4.5          4.0
# 1929          Ready supermarket | ረዲ ሱፐር ማርኬት             4.5         11.0
# 1930          Ready supermarket | ረዲ ሱፐር ማርኬት             4.5         11.0
# 1931          Ready supermarket | ረዲ ሱፐር ማርኬት             4.5         11.0
#
#            category            attributes  \
# 0       Supermarket  ·  In-store shopping
# 1       Supermarket  ·  In-store shopping
# 2       Supermarket  ·  In-store shopping
# 3     Grocery store  ·  In-store shopping
# 4       Supermarket  ·  In-store shopping
# ...             ...                   ...
# 1927     Restaurant            ·  Takeout
# 1928     Restaurant            ·  Takeout
# 1929  Shopping mall                   NaN
# 1930  Shopping mall                   NaN
# 1931  Shopping mall                   NaN
#
#                                                 address          wednesday  \
# 0     52 Roodebloem Rd, Woodstock, Cape Town, 7915, ...         7:30AM–8PM
# 1     52 Roodebloem Rd, Woodstock, Cape Town, 7915, ...         7:30AM–8PM
# 2     52 Roodebloem Rd, Woodstock, Cape Town, 7915, ...         7:30AM–8PM
# 3     Shop 6A, 31A Long St, Cape Town City Centre, C...            8AM–7PM
# 4     Corner House, Sea Point, Cape Town, 8005, Sout...     6:30AM–11:30PM
# ...                                                 ...                ...
# 1927                    2PWW+WVF, Addis Ababa, Ethiopia        8a.m.–9p.m.
# 1928                    2PWW+WVF, Addis Ababa, Ethiopia        8a.m.–9p.m.
# 1929                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
# 1930                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
# 1931                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
#
#                thursday             friday  ...             monday  \
# 0            7:30AM–8PM         7:30AM–8PM  ...         7:30AM–8PM
# 1            7:30AM–8PM         7:30AM–8PM  ...         7:30AM–8PM
# 2            7:30AM–8PM         7:30AM–8PM  ...         7:30AM–8PM
# 3               8AM–7PM            8AM–7PM  ...            8AM–7PM
# 4        6:30AM–11:30PM     6:30AM–11:30PM  ...     6:30AM–11:30PM
# ...                 ...                ...  ...                ...
# 1927        8a.m.–9p.m.        8a.m.–9p.m.  ...        8a.m.–9p.m.
# 1928        8a.m.–9p.m.        8a.m.–9p.m.  ...        8a.m.–9p.m.
# 1929  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  ...  6:30a.m.–1:30p.m.
# 1930  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  ...  6:30a.m.–1:30p.m.
# 1931  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  ...  6:30a.m.–1:30p.m.
#
#                 tuesday                          info  \
# 0            7:30AM–8PM  Hours or services may differ
# 1            7:30AM–8PM  Hours or services may differ
# 2            7:30AM–8PM  Hours or services may differ
# 3               8AM–7PM  Hours or services may differ
# 4        6:30AM–11:30PM  Hours or services may differ
# ...                 ...                           ...
# 1927        8a.m.–9p.m.                           NaN
# 1928        8a.m.–9p.m.                           NaN
# 1929  6:30a.m.–1:30p.m.                           NaN
# 1930  6:30a.m.–1:30p.m.                           NaN
# 1931  6:30a.m.–1:30p.m.                           NaN
#
#                                                  imgurl   latitude  longitude  \
# 0     https://lh5.googleusercontent.com/p/AF1QipOJZx... -33.933312  18.451812
# 1     https://lh5.googleusercontent.com/p/AF1QipOJZx... -33.933312  18.451812
# 2     https://lh5.googleusercontent.com/p/AF1QipOJZx... -33.933312  18.451812
# 3     https://lh6.googleusercontent.com/proxy/yEvgHH... -33.920313  18.421813
# 4     https://www.gstatic.com/images/icons/material/... -33.912937  18.391938
# ...                                                 ...        ...        ...
# 1927  https://lh5.googleusercontent.com/p/AF1QipPSlz...   9.047319  38.747162
# 1928  https://lh5.googleusercontent.com/p/AF1QipPSlz...   9.047319  38.747162
# 1929  https://lh5.googleusercontent.com/p/AF1QipN5aq...   8.980050  38.774962
# 1930  https://lh5.googleusercontent.com/p/AF1QipN5aq...   8.980050  38.774962
# 1931  https://lh5.googleusercontent.com/p/AF1QipN5aq...   8.980050  38.774962
#
#            query                                   reviewer rating  \
# 0           Lomé  Hair by Michelle and Beauty Parlour phala    5.0
# 1           Lomé                                Jayan Smart    5.0
# 2           Lomé                           Loretta Chan-Sam    5.0
# 3           Lomé                               محمود Mhmood    5.0
# 4           Lomé                           ANTHONY.capetown    5.0
# ...          ...                                        ...    ...
# 1927  AddisAbaba                              anteneh alemu    5.0
# 1928  AddisAbaba                            Philipous Girma    4.0
# 1929  AddisAbaba                                Josy Mulatu    5.0
# 1930  AddisAbaba                               Yared Fekede    5.0
# 1931  AddisAbaba                              Shreya Pillai    4.0
#
#                                                  review
# 0     This is a go to supermarket, they go out of th...
# 1     Simply the best corner store. Just make sure y...
# 2     If youre looking for a consumer-friendly par e...
# 3                                                   😉👍🏻
# 4     Amazingly friendly staff that make the neighbo...
# ...                                                 ...
# 1927  Amazing fresh vegetable, my favorite one from ...
# 1928                         Good service and Good food
# 1929  They have good communication with their consum...
# 1930                  Best Super Market in Bole Michael
# 1931  Very useful to have in Bole Michael, slightly ...
#
# [1932 rows x 22 columns]

# %%
print(reviews.columns)
print(missinglat.columns)
# Out:
# Index(['placeurl', 'placename', 'overall_rating', 'reviewcount', 'category',
#        'attributes', 'address', 'wednesday', 'thursday', 'friday', 'saturday',
#        'sunday', 'monday', 'tuesday', 'info', 'imgurl', 'latitude',
#        'longitude', 'query', 'reviewer', 'rating', 'review'],
#       dtype='object')

# %%
print(reviews.shape)
print(missinglat.shape)
# same number of columns
# Out:
# (517, 26)
# (775, 26)

# %%
reviews.dtypes
# Out:
# placeurl          object
# title             object
# rating           float64
# reviewcount      float64
# category          object
# attributes        object
# address           object
# pluscode          object
# website           object
# phonenumber       object
# wednesday         object
# thursday          object
# friday            object
# saturday          object
# sunday            object
# monday            object
# tuesday           object
# currentstatus     object
# info              object
# imgurl            object
# isclaimed           bool
# latitude         float64
# longitude        float64
# query             object
# timestamp         object
# reviews           object
# dtype: object

# %%
missinglat.dtypes
# same dtypes of columns
# Out:
# placeurl          object
# title             object
# rating           float64
# reviewcount      float64
# category          object
# attributes        object
# address           object
# pluscode          object
# website           object
# phonenumber       object
# wednesday         object
# thursday          object
# friday            object
# saturday          object
# sunday            object
# monday            object
# tuesday           object
# currentstatus     object
# info              object
# imgurl            object
# isclaimed           bool
# latitude         float64
# longitude        float64
# query             object
# timestamp         object
# reviews           object
# dtype: object

# %%
# append the two datasets
reviews = reviews.append(missinglat)

# %%
reviews
# Out:
#                                               placeurl  \
# 0    https://www.google.com/maps/place/S.E.+Superma...
# 1    https://www.google.com/maps/place/R+%26+K+Supe...
# 2    https://www.google.com/maps/place/Family+Super...
# 3    https://www.google.com/maps/place/City+Cafe+%2...
# 4    https://www.google.com/maps/place/Best+Price+S...
# ..                                                 ...
# 770  https://www.google.com/maps/place/Besh+Gebeya+...
# 771  https://www.google.com/maps/place/Mekdi+superm...
# 772  https://www.google.com/maps/place/Bashir+Super...
# 773  https://www.google.com/maps/place/Lege+Tafo+le...
# 774  https://www.google.com/maps/place/Negash+Super...
#
#                                title  rating  reviewcount       category  \
# 0                  S.E. Supermarkets     4.7         68.0    Supermarket
# 1                  R & K Supermarket     NaN          NaN  Grocery store
# 2                 Family Supermarket     NaN          NaN  Grocery store
# 3           City Cafe & Supermarkets     5.0          1.0  Grocery store
# 4             Best Price Supermarket     NaN          NaN  Grocery store
# ..                               ...     ...          ...            ...
# 770        Besh Gebeya - Ayat Branch     4.6          7.0    Supermarket
# 771                Mekdi supermarket     NaN          NaN    Supermarket
# 772               Bashir Supermarket     NaN          NaN          Store
# 773  Lege Tafo lege Dadi Supermarket     NaN          NaN         Market
# 774  Negash Supermarket, Addis Ababa     NaN          NaN         Market
#
#                attributes                                            address  \
# 0    ·  In-store shopping  52 Roodebloem Rd, Woodstock, Cape Town, 7915, ...
# 1    ·  In-store shopping          Salt River, Cape Town, 7925, South Africa
# 2    ·  In-store shopping  Cape Town City Centre, Cape Town, 8000, South ...
# 3    ·  In-store shopping  Shop 6A, 31A Long St, Cape Town City Centre, C...
# 4                     NaN          Salt River, Cape Town, 7925, South Africa
# ..                    ...                                                ...
# 770  ·  In-store shopping                Ayat Zone, 2, Addis Ababa, Ethiopia
# 771  ·  In-store shopping                            micheal, Bole, Ethiopia
# 772  ·  In-store shopping                Unnamed Road, Addis Ababa, Ethiopia
# 773                   NaN                       Gwala Dale Denibel, Ethiopia
# 774                   NaN                Roosevelt St, Addis Ababa, Ethiopia
#
#                             pluscode website       phonenumber  ...  \
# 0    3F82+MP Cape Town, South Africa     NaN   +27 21 447 4626  ...
# 1    3FC7+C2 Cape Town, South Africa     NaN               NaN  ...
# 2    3CJF+6W Cape Town, South Africa     NaN               NaN  ...
# 3    3CHC+VP Cape Town, South Africa     NaN   +27 84 867 6872  ...
# 4    3FC6+J5 Cape Town, South Africa     NaN               NaN  ...
# ..                               ...     ...               ...  ...
# 770    2V8C+7H Addis Ababa, Ethiopia     NaN  +251 11 551 4236  ...
# 771    XQMF+4G Addis Ababa, Ethiopia     NaN  +251 92 366 6706  ...
# 772    WPWQ+V3 Addis Ababa, Ethiopia     NaN               NaN  ...
# 773    3V7P+82 Addis Ababa, Ethiopia     NaN               NaN  ...
# 774    2P3R+7H Addis Ababa, Ethiopia     NaN               NaN  ...
#
#                tuesday                currentstatus  \
# 0           7:30AM–8PM         Open now  7:30AM–8PM
# 1                  NaN                          NaN
# 2                  NaN                          NaN
# 3              8AM–7PM            Open now  8AM–7PM
# 4                  NaN                          NaN
# ..                 ...                          ...
# 770  8:30a.m.–7:30p.m.  Open now  8:30a.m.–7:30p.m.
# 771      Open 24 hours      Open now  Open 24 hours
# 772                NaN                          NaN
# 773                NaN                          NaN
# 774                NaN                          NaN
#
#                              info  \
# 0    Hours or services may differ
# 1    Hours or services may differ
# 2    Hours or services may differ
# 3    Hours or services may differ
# 4                             NaN
# ..                            ...
# 770                           NaN
# 771                           NaN
# 772                           NaN
# 773                           NaN
# 774                           NaN
#
#                                                 imgurl isclaimed   latitude  \
# 0    https://lh5.googleusercontent.com/p/AF1QipOJZx...     False -33.933313
# 1    https://www.gstatic.com/images/icons/material/...     False -33.928938
# 2    https://lh5.googleusercontent.com/p/AF1QipNre6...     False -33.919438
# 3    https://lh6.googleusercontent.com/proxy/yEvgHH...     False -33.920313
# 4    https://maps.gstatic.com/tactile/pane/default_...     False -33.928438
# ..                                                 ...       ...        ...
# 770  https://www.gstatic.com/images/icons/material/...     False   9.015688
# 771  https://maps.gstatic.com/tactile/pane/default_...     False   8.982812
# 772  https://maps.gstatic.com/tactile/pane/default_...     False   8.947188
# 773  https://maps.gstatic.com/tactile/pane/default_...     False   9.063312
# 774  https://lh5.googleusercontent.com/p/AF1QipMbii...     False   9.003187
#
#      longitude       query                 timestamp  \
# 0    18.451812        Lomé  2021-10-20T10:15:46.195Z
# 1    18.462562        Lomé  2021-10-20T10:15:50.950Z
# 2    18.424813        Lomé  2021-10-20T10:15:55.919Z
# 3    18.421813        Lomé  2021-10-20T10:16:00.191Z
# 4    18.460437        Lomé  2021-10-20T10:16:05.964Z
# ..         ...         ...                       ...
# 770  38.871437  AddisAbaba  2021-10-21T07:39:23.555Z
# 771  38.773813  AddisAbaba  2021-10-21T07:39:28.866Z
# 772  38.737687  AddisAbaba  2021-10-21T07:39:39.853Z
# 773  38.885062  AddisAbaba  2021-10-21T07:39:53.268Z
# 774  38.741437  AddisAbaba  2021-10-21T07:40:00.638Z
#
#                                                reviews
# 0    [{'title': 'Hair by Michelle and Beauty Parlou...
# 1                                                   []
# 2                                                   []
# 3    [{'title': 'محمود Mhmood', 'rating': '5', 'bod...
# 4                                                   []
# ..                                                 ...
# 770  [{'title': 'Mel Bek', 'rating': '5', 'body': "...
# 771                                                 []
# 772                                                 []
# 773                                                 []
# 774                                                 []
#
# [1292 rows x 26 columns]

# %%
# reset index
reviews = reviews.reset_index(drop=True)
reviews
# Out:
#                                                placeurl  \
# 0     https://www.google.com/maps/place/S.E.+Superma...
# 1     https://www.google.com/maps/place/R+%26+K+Supe...
# 2     https://www.google.com/maps/place/Family+Super...
# 3     https://www.google.com/maps/place/City+Cafe+%2...
# 4     https://www.google.com/maps/place/Best+Price+S...
# ...                                                 ...
# 1287  https://www.google.com/maps/place/Besh+Gebeya+...
# 1288  https://www.google.com/maps/place/Mekdi+superm...
# 1289  https://www.google.com/maps/place/Bashir+Super...
# 1290  https://www.google.com/maps/place/Lege+Tafo+le...
# 1291  https://www.google.com/maps/place/Negash+Super...
#
#                                 title  rating  reviewcount       category  \
# 0                   S.E. Supermarkets     4.7         68.0    Supermarket
# 1                   R & K Supermarket     NaN          NaN  Grocery store
# 2                  Family Supermarket     NaN          NaN  Grocery store
# 3            City Cafe & Supermarkets     5.0          1.0  Grocery store
# 4              Best Price Supermarket     NaN          NaN  Grocery store
# ...                               ...     ...          ...            ...
# 1287        Besh Gebeya - Ayat Branch     4.6          7.0    Supermarket
# 1288                Mekdi supermarket     NaN          NaN    Supermarket
# 1289               Bashir Supermarket     NaN          NaN          Store
# 1290  Lege Tafo lege Dadi Supermarket     NaN          NaN         Market
# 1291  Negash Supermarket, Addis Ababa     NaN          NaN         Market
#
#                 attributes                                            address  \
# 0     ·  In-store shopping  52 Roodebloem Rd, Woodstock, Cape Town, 7915, ...
# 1     ·  In-store shopping          Salt River, Cape Town, 7925, South Africa
# 2     ·  In-store shopping  Cape Town City Centre, Cape Town, 8000, South ...
# 3     ·  In-store shopping  Shop 6A, 31A Long St, Cape Town City Centre, C...
# 4                      NaN          Salt River, Cape Town, 7925, South Africa
# ...                    ...                                                ...
# 1287  ·  In-store shopping                Ayat Zone, 2, Addis Ababa, Ethiopia
# 1288  ·  In-store shopping                            micheal, Bole, Ethiopia
# 1289  ·  In-store shopping                Unnamed Road, Addis Ababa, Ethiopia
# 1290                   NaN                       Gwala Dale Denibel, Ethiopia
# 1291                   NaN                Roosevelt St, Addis Ababa, Ethiopia
#
#                              pluscode website       phonenumber  ...  \
# 0     3F82+MP Cape Town, South Africa     NaN   +27 21 447 4626  ...
# 1     3FC7+C2 Cape Town, South Africa     NaN               NaN  ...
# 2     3CJF+6W Cape Town, South Africa     NaN               NaN  ...
# 3     3CHC+VP Cape Town, South Africa     NaN   +27 84 867 6872  ...
# 4     3FC6+J5 Cape Town, South Africa     NaN               NaN  ...
# ...                               ...     ...               ...  ...
# 1287    2V8C+7H Addis Ababa, Ethiopia     NaN  +251 11 551 4236  ...
# 1288    XQMF+4G Addis Ababa, Ethiopia     NaN  +251 92 366 6706  ...
# 1289    WPWQ+V3 Addis Ababa, Ethiopia     NaN               NaN  ...
# 1290    3V7P+82 Addis Ababa, Ethiopia     NaN               NaN  ...
# 1291    2P3R+7H Addis Ababa, Ethiopia     NaN               NaN  ...
#
#                 tuesday                currentstatus  \
# 0            7:30AM–8PM         Open now  7:30AM–8PM
# 1                   NaN                          NaN
# 2                   NaN                          NaN
# 3               8AM–7PM            Open now  8AM–7PM
# 4                   NaN                          NaN
# ...                 ...                          ...
# 1287  8:30a.m.–7:30p.m.  Open now  8:30a.m.–7:30p.m.
# 1288      Open 24 hours      Open now  Open 24 hours
# 1289                NaN                          NaN
# 1290                NaN                          NaN
# 1291                NaN                          NaN
#
#                               info  \
# 0     Hours or services may differ
# 1     Hours or services may differ
# 2     Hours or services may differ
# 3     Hours or services may differ
# 4                              NaN
# ...                            ...
# 1287                           NaN
# 1288                           NaN
# 1289                           NaN
# 1290                           NaN
# 1291                           NaN
#
#                                                  imgurl isclaimed   latitude  \
# 0     https://lh5.googleusercontent.com/p/AF1QipOJZx...     False -33.933313
# 1     https://www.gstatic.com/images/icons/material/...     False -33.928938
# 2     https://lh5.googleusercontent.com/p/AF1QipNre6...     False -33.919438
# 3     https://lh6.googleusercontent.com/proxy/yEvgHH...     False -33.920313
# 4     https://maps.gstatic.com/tactile/pane/default_...     False -33.928438
# ...                                                 ...       ...        ...
# 1287  https://www.gstatic.com/images/icons/material/...     False   9.015688
# 1288  https://maps.gstatic.com/tactile/pane/default_...     False   8.982812
# 1289  https://maps.gstatic.com/tactile/pane/default_...     False   8.947188
# 1290  https://maps.gstatic.com/tactile/pane/default_...     False   9.063312
# 1291  https://lh5.googleusercontent.com/p/AF1QipMbii...     False   9.003187
#
#       longitude       query                 timestamp  \
# 0     18.451812        Lomé  2021-10-20T10:15:46.195Z
# 1     18.462562        Lomé  2021-10-20T10:15:50.950Z
# 2     18.424813        Lomé  2021-10-20T10:15:55.919Z
# 3     18.421813        Lomé  2021-10-20T10:16:00.191Z
# 4     18.460437        Lomé  2021-10-20T10:16:05.964Z
# ...         ...         ...                       ...
# 1287  38.871437  AddisAbaba  2021-10-21T07:39:23.555Z
# 1288  38.773813  AddisAbaba  2021-10-21T07:39:28.866Z
# 1289  38.737687  AddisAbaba  2021-10-21T07:39:39.853Z
# 1290  38.885062  AddisAbaba  2021-10-21T07:39:53.268Z
# 1291  38.741437  AddisAbaba  2021-10-21T07:40:00.638Z
#
#                                                 reviews
# 0     [{'title': 'Hair by Michelle and Beauty Parlou...
# 1                                                    []
# 2                                                    []
# 3     [{'title': 'محمود Mhmood', 'rating': '5', 'bod...
# 4                                                    []
# ...                                                 ...
# 1287  [{'title': 'Mel Bek', 'rating': '5', 'body': "...
# 1288                                                 []
# 1289                                                 []
# 1290                                                 []
# 1291                                                 []
#
# [1292 rows x 26 columns]

# %% [markdown]
# ## Clean the reviews column

# %%
reviews['reviews'][1291]
# Out:
# '[]'

# %%
# How many reviews are empty in the new dataframe ?
(reviews['reviews']=='[]').sum()
# Out:
# 142

# %%
# drop empty reviews rows
reviews = reviews[reviews['reviews'] != '[]']

# %%
# other kind of null values ?
reviews['reviews'].isna().sum()
# Out:
# 517

# %%
# drop null values from the review column
reviews = reviews[reviews['reviews'].notna()]

# %%
# distribution of reviews over cities
reviews['query'].value_counts()
# Out:
# Nairobi       221
# Lomé          148
# CapeTown      119
# Yaoundé        90
# AddisAbaba     55
# Name: query, dtype: int64

# %%
# are there duplicate rows ?
print(reviews['placeurl'].size)
print(reviews['placeurl'].drop_duplicates().size)
# Out:
# 633
# 582

# %%
print(reviews['reviews'].size)
print(reviews['reviews'].drop_duplicates().size)
# yes
# Out:
# 633
# 581

# %%
reviews = reviews.drop_duplicates(subset = 'reviews', keep = 'first')

# %%
reviews.shape
# Out:
# (581, 26)

# %%
reviews.columns

# %%
# drop useless columns
reviews=reviews.drop([#'Unnamed: 0',
                                'website',
                                'pluscode',
                                'phonenumber',
                                'currentstatus',
                                'isclaimed',
                                'timestamp'
                               ], axis=1)

# %%
reviews['reviews'][0]

# %%
# split reviews column in individual row for each review
new_df = reviews['reviews'].str.split('}, ').apply(pd.Series, 1).stack()
# match index with medium df index
new_df.index = new_df.index.droplevel(-1)
# name to join
new_df.name = 'reviews'

# %%
#delete original reviews column
del reviews['reviews']

# %%
# import new expanded column in dataframe
reviews = reviews.join(new_df)
reviews = reviews.reset_index(drop=True)
reviews.head()

# %%
# reset index
reviews = reviews.drop(['index'], axis=1)
reviews.head()

# %%
# rename 'title' column in 'placename' and 'rating' in 'overall_rating'
reviews.rename(columns={'rating': 'overall_rating',
                       'title': 'placename'
                      }, inplace=True, errors='raise')

# %%
reviews['reviews'][0]

# %%
# split the reviews column in title, rating , body
review_split = pd.concat([reviews['placeurl'], reviews['reviews'].str.split('\', ', expand=True)], axis=1)
review_split.head()

# %%
#check nulls
review_split.isna().sum()

# %%
# where are the errors ?
review_split['rating'].value_counts()

# %% [markdown]
# #### the 13 missing reviews are in the rating column. probably due to an error at the split

# %%
# get rows containing 'body' in the rating column
missing_split = review_split[review_split['rating'].str.contains("body")]
missing_split

# %%
# check syntax
missing_split['reviewer'][267]

# %%
# drop empty review column
del missing_split['review']

# %%
# split the missing splits on specific syntax
missing_split = pd.concat([missing_split['placeurl'], missing_split['reviewer'].str.split('", \'', expand=True), missing_split['2']], axis=1)
missing_split

# %%
# replace missing review_split rows with the ones corrected
indices = [267,392,544,589,610,909,980,1162,1344,1347,1355,1371,1548]

for i in indices:
    review_split.loc[i,'reviewer'] = missing_split.loc[i,0]
    review_split.loc[i,'rating'] = missing_split.loc[i,1]
    review_split.loc[i,'review'] = missing_split.loc[i,'rating']

# %%
review_split.loc[267]

# %%
review_split.isna().sum()

# %%
# rename newly created columns
review_split.rename(columns={0: 'reviewer',
                        1: 'rating',
                        2: 'review'
                      }, inplace=True, errors='raise')
review_split.head()

# %%
print(review_split['reviewer'][0])
print(review_split['rating'][0])
print(review_split['review'][0])

# %%
# clean the columns
review_split['reviewer'] = review_split['reviewer'].str.replace("{'title': '",'')
review_split['reviewer'] = review_split['reviewer'].str.replace("[",'')
review_split['reviewer'] = review_split['reviewer'].str.replace("{'title': ",'')
review_split['reviewer'] = review_split['reviewer'].str.replace('"','')
review_split['rating'] = review_split['rating'].str.replace("'rating': '",'')
review_split['rating'] = review_split['rating'].str.replace("rating': '",'')
review_split['review'] = review_split['review'].str.replace("'body': ",'')
review_split['review'] = review_split['review'].str.replace("]",'')
review_split['review'] = review_split['review'].str.replace("}",'')
review_split['review'] = review_split['review'].str.replace("'",'')
review_split['review'] = review_split['review'].str.replace('"','')

# %%
# check clean result
print(review_split['reviewer'][0])
print(review_split['rating'][0])
print(review_split['review'][0])

# %%
# check clean result on the corrected ones
print(review_split['reviewer'][909])
print(review_split['rating'][909])
print(review_split['review'][909])

# %%
# merge with main reviews file
reviews = pd.merge(
    left=reviews,
    right=review_split,
    on='placeurl',
    how='left'
)
reviews.head()

# %%
#drop duplicate
reviews = reviews.drop_duplicates(keep='first',inplace=False)
# reset index
reviews = reviews.reset_index(drop=True)
reviews
# Out:
#                                                placeurl  \
# 0     https://www.google.com/maps/place/S.E.+Superma...
# 1     https://www.google.com/maps/place/S.E.+Superma...
# 2     https://www.google.com/maps/place/S.E.+Superma...
# 3     https://www.google.com/maps/place/City+Cafe+%2...
# 4     https://www.google.com/maps/place/Brothers+Sup...
# ...                                                 ...
# 1927  https://www.google.com/maps/place/Wina+Superma...
# 1928  https://www.google.com/maps/place/Wina+Superma...
# 1929  https://www.google.com/maps/place/Ready+superm...
# 1930  https://www.google.com/maps/place/Ready+superm...
# 1931  https://www.google.com/maps/place/Ready+superm...
#
#                                     placename  overall_rating  reviewcount  \
# 0                           S.E. Supermarkets             4.7         68.0
# 1                           S.E. Supermarkets             4.7         68.0
# 2                           S.E. Supermarkets             4.7         68.0
# 3                    City Cafe & Supermarkets             5.0          1.0
# 4                        Brothers Supermarket             4.0          9.0
# ...                                       ...             ...          ...
# 1927  Wina Supermarket And Juice Shola Branch             4.5          4.0
# 1928  Wina Supermarket And Juice Shola Branch             4.5          4.0
# 1929          Ready supermarket | ረዲ ሱፐር ማርኬት             4.5         11.0
# 1930          Ready supermarket | ረዲ ሱፐር ማርኬት             4.5         11.0
# 1931          Ready supermarket | ረዲ ሱፐር ማርኬት             4.5         11.0
#
#            category            attributes  \
# 0       Supermarket  ·  In-store shopping
# 1       Supermarket  ·  In-store shopping
# 2       Supermarket  ·  In-store shopping
# 3     Grocery store  ·  In-store shopping
# 4       Supermarket  ·  In-store shopping
# ...             ...                   ...
# 1927     Restaurant            ·  Takeout
# 1928     Restaurant            ·  Takeout
# 1929  Shopping mall                   NaN
# 1930  Shopping mall                   NaN
# 1931  Shopping mall                   NaN
#
#                                                 address          wednesday  \
# 0     52 Roodebloem Rd, Woodstock, Cape Town, 7915, ...         7:30AM–8PM
# 1     52 Roodebloem Rd, Woodstock, Cape Town, 7915, ...         7:30AM–8PM
# 2     52 Roodebloem Rd, Woodstock, Cape Town, 7915, ...         7:30AM–8PM
# 3     Shop 6A, 31A Long St, Cape Town City Centre, C...            8AM–7PM
# 4     Corner House, Sea Point, Cape Town, 8005, Sout...     6:30AM–11:30PM
# ...                                                 ...                ...
# 1927                    2PWW+WVF, Addis Ababa, Ethiopia        8a.m.–9p.m.
# 1928                    2PWW+WVF, Addis Ababa, Ethiopia        8a.m.–9p.m.
# 1929                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
# 1930                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
# 1931                    XQJF+2X8, Addis Ababa, Ethiopia  6:30a.m.–1:30p.m.
#
#                thursday             friday  ...             monday  \
# 0            7:30AM–8PM         7:30AM–8PM  ...         7:30AM–8PM
# 1            7:30AM–8PM         7:30AM–8PM  ...         7:30AM–8PM
# 2            7:30AM–8PM         7:30AM–8PM  ...         7:30AM–8PM
# 3               8AM–7PM            8AM–7PM  ...            8AM–7PM
# 4        6:30AM–11:30PM     6:30AM–11:30PM  ...     6:30AM–11:30PM
# ...                 ...                ...  ...                ...
# 1927        8a.m.–9p.m.        8a.m.–9p.m.  ...        8a.m.–9p.m.
# 1928        8a.m.–9p.m.        8a.m.–9p.m.  ...        8a.m.–9p.m.
# 1929  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  ...  6:30a.m.–1:30p.m.
# 1930  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  ...  6:30a.m.–1:30p.m.
# 1931  6:30a.m.–1:30p.m.  6:30a.m.–1:30p.m.  ...  6:30a.m.–1:30p.m.
#
#                 tuesday                          info  \
# 0            7:30AM–8PM  Hours or services may differ
# 1            7:30AM–8PM  Hours or services may differ
# 2            7:30AM–8PM  Hours or services may differ
# 3               8AM–7PM  Hours or services may differ
# 4        6:30AM–11:30PM  Hours or services may differ
# ...                 ...                           ...
# 1927        8a.m.–9p.m.                           NaN
# 1928        8a.m.–9p.m.                           NaN
# 1929  6:30a.m.–1:30p.m.                           NaN
# 1930  6:30a.m.–1:30p.m.                           NaN
# 1931  6:30a.m.–1:30p.m.                           NaN
#
#                                                  imgurl   latitude  longitude  \
# 0     https://lh5.googleusercontent.com/p/AF1QipOJZx... -33.933313  18.451812
# 1     https://lh5.googleusercontent.com/p/AF1QipOJZx... -33.933313  18.451812
# 2     https://lh5.googleusercontent.com/p/AF1QipOJZx... -33.933313  18.451812
# 3     https://lh6.googleusercontent.com/proxy/yEvgHH... -33.920313  18.421813
# 4     https://www.gstatic.com/images/icons/material/... -33.912938  18.391938
# ...                                                 ...        ...        ...
# 1927  https://lh5.googleusercontent.com/p/AF1QipPSlz...   9.047319  38.747162
# 1928  https://lh5.googleusercontent.com/p/AF1QipPSlz...   9.047319  38.747162
# 1929  https://lh5.googleusercontent.com/p/AF1QipN5aq...   8.980050  38.774962
# 1930  https://lh5.googleusercontent.com/p/AF1QipN5aq...   8.980050  38.774962
# 1931  https://lh5.googleusercontent.com/p/AF1QipN5aq...   8.980050  38.774962
#
#            query                                   reviewer rating  \
# 0           Lomé  Hair by Michelle and Beauty Parlour phala    5.0
# 1           Lomé                                Jayan Smart    5.0
# 2           Lomé                           Loretta Chan-Sam    5.0
# 3           Lomé                               محمود Mhmood    5.0
# 4           Lomé                           ANTHONY.capetown    5.0
# ...          ...                                        ...    ...
# 1927  AddisAbaba                              anteneh alemu      5
# 1928  AddisAbaba                            Philipous Girma      4
# 1929  AddisAbaba                                Josy Mulatu      5
# 1930  AddisAbaba                               Yared Fekede      5
# 1931  AddisAbaba                              Shreya Pillai      4
#
#                                                  review
# 0     This is a go to supermarket, they go out of th...
# 1     Simply the best corner store. Just make sure y...
# 2     If youre looking for a consumer-friendly par e...
# 3                                                   😉👍🏻
# 4     Amazingly friendly staff that make the neighbo...
# ...                                                 ...
# 1927  Amazing fresh vegetable, my favorite one from ...
# 1928                         Good service and Good food
# 1929  They have good communication with their consum...
# 1930                  Best Super Market in Bole Michael
# 1931  Very useful to have in Bole Michael, slightly ...
#
# [1932 rows x 22 columns]

# %%
# check nulls
reviews.isna().sum()
# Out:
# placeurl             0
# placename            0
# overall_rating       1
# reviewcount          1
# category             0
# attributes         144
# address              0
# wednesday          261
# thursday           261
# friday             261
# saturday           261
# sunday             261
# monday             261
# tuesday            261
# info              1676
# imgurl               0
# latitude             0
# longitude            0
# query                0
# reviewer             0
# rating             173
# review             233
# dtype: int64

# %%
reviews['rating'].value_counts()
# Out:
# 5.0    853
# 4.0    476
# 3.0    326
# 2.0    104
# Name: rating, dtype: int64

# %%
reviews['rating'].dtype
# Out:
# dtype('float64')

# %%
# save reviews file
#reviews.to_csv('GM_reviews.csv', index=False)

# %% [markdown]
# # EDA on reviews

# %%
reviews = pd.read_csv('/Users/juliencarbonnell/Desktop/African Urban Research/datasets/GM_reviews.csv')

# %%
reviews.columns
# Out:
# Index(['placeurl', 'placename', 'overall_rating', 'reviewcount', 'category',
#        'attributes', 'address', 'wednesday', 'thursday', 'friday', 'saturday',
#        'sunday', 'monday', 'tuesday', 'info', 'imgurl', 'latitude',
#        'longitude', 'query', 'reviewer', 'rating', 'review'],
#       dtype='object')

# %%
# how many supermarkets do we have in each city
reviews.drop_duplicates(subset='placeurl',keep='first').groupby(['city'])['city'].count().sort_values(ascending=False)
# Out:
# city
# Nairobi        185
# Cape Town      148
# Yaoundé        141
# Addis Ababa    101
# Lomé            90
# Name: city, dtype: int64

# %%
# statistical overview of the supermarkets of our dataset
reviews.drop_duplicates(subset='placeurl',keep='first').describe()
# Out:
#        overall_rating  reviewcount    latitude   longitude      rating
# count      664.000000   664.000000  665.000000  665.000000  616.000000
# mean         3.894578   267.347892   -4.882276   22.849013    4.207792
# std          0.687423   578.387359   15.935734   13.724335    0.902933
# min          1.000000     1.000000  -34.031813    0.742687    2.000000
# 25%          3.600000     3.000000   -1.326426   11.518937    4.000000
# 50%          3.950000    18.500000   -0.776813   18.469812    4.000000
# 75%          4.300000   240.000000    6.134563   36.891438    5.000000
# max          5.000000  5092.000000    9.070813   38.969437    5.000000

# %%
# mean of overall_ratings in each city
reviews.drop_duplicates(subset='placeurl',keep='first').groupby(['city'])['overall_rating'].mean().sort_values(ascending=False)
# Out:
# city
# Cape Town      4.029730
# Nairobi        3.936757
# Addis Ababa    3.929703
# Lomé           3.852222
# Yaoundé        3.697857
# Name: overall_rating, dtype: float64

# %%
# mean number of reviews for each city
reviews.drop_duplicates(subset='placeurl',keep='first').groupby(['city'])['reviewcount'].mean().sort_values(ascending=False)
# Out:
# city
# Nairobi        499.545946
# Cape Town      325.587838
# Yaoundé        174.907143
# Lomé           127.355556
# Addis Ababa      9.574257
# Name: reviewcount, dtype: float64

# %%
# counts the categories of supermarkets in total
reviews.drop_duplicates(subset='placeurl',keep='first')['category'].value_counts()
# Out:
# Supermarket                         431
# Grocery store                       179
# Shopping mall                         8
# Chinese supermarket                   6
# Shop supermarket furniture store      5
# Convenience store                     4
# Market                                4
# Discount supermarket                  3
# General store                         3
# Home goods store                      2
# Clothing store                        2
# Travel agency                         1
# Hardware store                        1
# Hotel                                 1
# Greengrocer                           1
# Make-up artist                        1
# E-commerce service                    1
# Hypermarket                           1
# Money transfer service                1
# Natural goods store                   1
# Variety store                         1
# Butcher shop                          1
# Fresh food market                     1
# Fruit and vegetable processing        1
# Coffee shop                           1
# Spice store                           1
# Fruit and vegetable store             1
# Restaurant                            1
# Store                                 1
# Name: category, dtype: int64

# %%
# counts the categories of supermarkets for each city
reviews.drop_duplicates(subset='placeurl',keep='first').groupby(['city'])['category'].value_counts()
# Out:
# city         category
# Addis Ababa  Supermarket                          64
#              Grocery store                        31
#              Shopping mall                         4
#              Discount supermarket                  1
#              Restaurant                            1
# Cape Town    Grocery store                        66
#              Supermarket                          65
#              Convenience store                     4
#              Chinese supermarket                   2
#              Butcher shop                          1
#              Clothing store                        1
#              Coffee shop                           1
#              Fresh food market                     1
#              Fruit and vegetable processing        1
#              Fruit and vegetable store             1
#              General store                         1
#              Home goods store                      1
#              Natural goods store                   1
#              Shop supermarket furniture store      1
#              Spice store                           1
# Lomé         Supermarket                          72
#              Grocery store                        10
#              Market                                3
#              Clothing store                        1
#              Home goods store                      1
#              Shop supermarket furniture store      1
#              Shopping mall                         1
#              Variety store                         1
# Nairobi      Supermarket                         145
#              Grocery store                        33
#              Chinese supermarket                   4
#              General store                         1
#              Greengrocer                           1
#              Money transfer service                1
# Yaoundé      Supermarket                          85
#              Grocery store                        39
#              Shop supermarket furniture store      3
#              Shopping mall                         3
#              Discount supermarket                  2
#              E-commerce service                    1
#              General store                         1
#              Hardware store                        1
#              Hotel                                 1
#              Hypermarket                           1
#              Make-up artist                        1
#              Market                                1
#              Store                                 1
#              Travel agency                         1
# Name: category, dtype: int64

# %% [markdown]
# #### how many of them propose a Delivery service ?

# %%
# delete null attributes
delivery = reviews[reviews['attributes'].notna()]

# %%
# extract attributes mentionning delivery
delivery = delivery[delivery['attributes'].str.contains("Delivery")]

# %%
# dropduplicate and groupby city
delivery.drop_duplicates(subset='placeurl',keep='first').groupby(['city'])['city'].value_counts()
# Out:
# city         city
# Addis Ababa  Addis Ababa      1
# Cape Town    Cape Town       30
# Lomé         Lomé            19
# Nairobi      Nairobi        123
# Yaoundé      Yaoundé         29
# Name: city, dtype: int64

# %%
# how many supermarkets are closed on each day?
print('mondays closed :', reviews.drop_duplicates(subset='placeurl',keep='first')[reviews['monday']=="Closed"].shape[0])
print('tuesdays closed :', reviews.drop_duplicates(subset='placeurl',keep='first')[reviews['tuesday']=="Closed"].shape[0])
print('wednesdays closed :', reviews.drop_duplicates(subset='placeurl',keep='first')[reviews['wednesday']=="Closed"].shape[0])
print('thursdays closed :', reviews.drop_duplicates(subset='placeurl',keep='first')[reviews['thursday']=="Closed"].shape[0])
print('fridays closed :', reviews.drop_duplicates(subset='placeurl',keep='first')[reviews['friday']=="Closed"].shape[0])
print('saturdays closed :', reviews.drop_duplicates(subset='placeurl',keep='first')[reviews['saturday']=="Closed"].shape[0])
print('sundays closed :', reviews.drop_duplicates(subset='placeurl',keep='first')[reviews['sunday']=="Closed"].shape[0])
# Out:
# mondays closed : 7
# tuesdays closed : 7
# wednesdays closed : 9
# thursdays closed : 9
# fridays closed : 8
# saturdays closed : 9
# sundays closed : 102

# %%
# check number of closed supermarkets on sunday by city
reviews.drop_duplicates(subset='placeurl',keep='first')[reviews['sunday']=="Closed"].groupby('city')['city'].count().sort_values(ascending=False)
# Out:
# city
# Nairobi        41
# Yaoundé        22
# Lomé           16
# Cape Town      14
# Addis Ababa     9
# Name: city, dtype: int64

# %%
# in terms of percentage ?
print(round(14*100/148,2),'% of the supermarkets in Cape Town are closed on sundays')
print(round(16*100/90,2),'% of the supermarkets in Lomé are closed on sundays')
print(round(22*100/141,2),'% of the supermarkets in Yaoundé are closed on sundays')
print(round(41*100/185,2),'% of the supermarkets in Nairobi are closed on sundays')
print(round(9*100/101,2),'% of the supermarkets in Addis Ababa are closed on sundays')
# Out:
# 9.46 % of the supermarkets in Cape Town are closed on sundays
# 17.78 % of the supermarkets in Lomé are closed on sundays
# 15.6 % of the supermarkets in Yaoundé are closed on sundays
# 22.16 % of the supermarkets in Nairobi are closed on sundays
# 8.91 % of the supermarkets in Addis Ababa are closed on sundays

# %%
#cluster lat/long to check if there are spatial correlation of ratings

# %% [markdown]
# # Map supermarkets on cities

# %%
# enter city coordinates
CapeTown=[-33.9249,18.4241]
Lomé=[6.1256,1.2254]
Yaoundé=[3.8480,11.5021]
Nairobi=[-1.2921,36.8219]
AddisAbaba=[8.9806,38.7578]

# generate maps
map_capetown = folium.Map(location=CapeTown,zoom_start=12)
map_lome = folium.Map(location=Lomé,zoom_start=12)
map_yaounde = folium.Map(location=Yaoundé,zoom_start=12)
map_nairobi = folium.Map(location=Nairobi,zoom_start=12)
map_addisababa = folium.Map(location=AddisAbaba,zoom_start=12)

# %%
# map supermarkets
for lat, long in zip(reviews['latitude'],
                    reviews['longitude']):
    folium.CircleMarker([lat, long],
                        radius=2, 
                        stroke=False, 
                        fill_color='blue',
                        fill_opacity=0.5).add_to(map_capetown)

map_capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_77920358128b4065a00505c8c4feb284%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_77920358128b4065a00505c8c4feb284%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_77920358128b4065a00505c8c4feb284%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_77920358128b4065a00505c8c4feb284%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-33.9249%2C%2018.4241%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# map supermarkets ratings
for lat, long, rating in zip(reviews['latitude'],
                             reviews['longitude'],
                             reviews['overall_rating']):
    folium.Marker(location=[lat,long],
                  icon=folium.DivIcon(
                      html=rating,
                  )).add_to(map_capetown)

map_capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4c20436555284f73a6d7c83467461205%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4c20436555284f73a6d7c83467461205%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4c20436555284f73a6d7c83467461205%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4c20436555284f73a6d7c83467461205%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-33.9249%2C%2018.4241%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# select non null dataset
ratings = reviews[reviews['overall_rating'].notna()]

# heatmap the ratings ()
heatmap = folium.Map(location=CapeTown,zoom_start=12)

locs = zip(ratings['latitude'],
           ratings['longitude'],
           ratings['overall_rating'])

HeatMap(locs, radius=15, blur=5).add_to(heatmap)

heatmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_45e4bd43524b4cfcaa4d0f11ebbce42a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//leaflet.github.io/Leaflet.heat/dist/leaflet-heat.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_45e4bd43524b4cfcaa4d0f11ebbce42a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_45e4bd43524b4cfcaa4d0f11ebbce42a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_45e4bd43524b4cfcaa4d0f11ebbce42a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ### technically working but hardly readable. seems like having errors
